# %% [markdown]
# # Data Exploration

# %%
DATA_PATH = "../data/raw/survey_results_public.csv"

# %%
#import some libraries
import pandas as pd 
import numpy as np 
pd.options.display.max_rows = 10000

# %%
# Read Data from CSV and printing Shape of Data
raw_df = pd.read_csv(DATA_PATH)
raw_df.shape
# Out:
# (83439, 48)

# %%
raw_df.sample(3)
# Out:
#        ResponseId                              MainBranch          Employment  \
# 5887         5888  I am a student who is learning to code  Student, full-time
# 30110       30111          I am a developer by profession  Employed full-time
# 46653       46654          I am a developer by profession  Employed full-time
#
#         Country US_State UK_Country  \
# 5887     Turkey      NaN        NaN
# 30110  Portugal      NaN        NaN
# 46653    Canada      NaN        NaN
#
#                                                  EdLevel     Age1stCode  \
# 5887   Some college/university study without earning ...  18 - 24 years
# 30110       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
# 46653       Bachelor’s degree (B.A., B.S., B.Eng., etc.)  11 - 17 years
#
#                                                LearnCode YearsCode  ...  \
# 5887   Other online resources (ex: videos, blogs, etc...         3  ...
# ...

# %%
raw_df.sample(3).iloc[0]
# Out:
# ResponseId                                                                   2834
# MainBranch                                         I am a developer by profession
# Employment                                                     Employed full-time
# Country                         United Kingdom of Great Britain and Northern I...
# US_State                                                                      NaN
# UK_Country                                                                England
# EdLevel                              Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# Age1stCode                                                          18 - 24 years
# LearnCode                       Other online resources (ex: videos, blogs, etc...
# YearsCode                                                                       6
# YearsCodePro                                                                    3
# ...

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %%
raw_df.describe()
# Out:
#          ResponseId     CompTotal  ConvertedCompYearly
# count  83439.000000  4.718300e+04         4.684400e+04
# mean   41720.000000  2.119407e+69         1.184262e+05
# std    24086.908893  4.603702e+71         5.272944e+05
# min        1.000000  0.000000e+00         1.000000e+00
# 25%    20860.500000  1.600000e+04         2.702500e+04
# 50%    41720.000000  6.700000e+04         5.621100e+04
# 75%    62579.500000  1.400000e+05         1.000000e+05
# max    83439.000000  1.000000e+74         4.524131e+07

# %%
questionable_cols = ['YearsCode', 'YearsCodePro']

for col in questionable_cols:
    print(col)
    print(raw_df[col].unique().tolist())
    print('-------------------------')
    print()
    #print(raw_df[col].unique())
# Out:
# YearsCode
# [nan, '7', '17', '3', '4', '6', '16', '12', '15', '10', '40', '9', '26', '14', '39', '20', '8', '19', '5', 'Less than 1 year', '22', '2', '1', '34', '21', '13', '25', '24', '30', '31', '18', '38', 'More than 50 years', '27', '41', '42', '35', '23', '28', '11', '37', '44', '43', '36', '33', '45', '29', '50', '46', '32', '47', '49', '48']
# -------------------------
#
# YearsCodePro
# [nan, '10', '4', '5', '6', '2', '30', '9', '18', '12', '21', '1', '16', 'Less than 1 year', '15', '3', '35', '7', '8', '17', '14', '26', '25', '20', '50', '34', '11', '24', '22', '13', '31', '23', '39', '41', '27', '28', '19', '33', 'More than 50 years', '37', '29', '32', '43', '40', '38', '45', '42', '46', '36', '44', '47', '48', '49']
# -------------------------

# %% [markdown]
# **From her we can see that YearsCode and YearsCodePro are not in the same format**
#
# **also they have some different datatypes we should make some data preprocessing on it.**
